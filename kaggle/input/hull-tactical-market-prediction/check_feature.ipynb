# %%
import pandas as pd

# %%
feature = pd.read_pickle('features/aqr_quality.pkl')
feature
# Out:
# asset       000001.SZ  000002.SZ  000003.SZ  000004.SZ  000005.SZ  000006.SZ  \
# date
# 1998-01-31   0.381888  -0.714090  -1.317665   0.097629  -1.337199   0.307855
# 1998-02-28   0.436222  -0.753135  -1.380194   0.164162  -1.387355   0.304242
# 1998-03-31   0.435245  -0.235230  -0.455255   0.974671  -0.362838   0.787834
# 1998-04-30   1.184156  -0.106293  -0.743089  -0.515288   0.898202   0.111087
# 1998-05-31   1.491739  -0.086033  -0.762953  -0.536885   1.208622   0.171426
# ...               ...        ...        ...        ...        ...        ...
# 2024-04-30   0.141188  -0.627671        NaN  -0.846966        NaN  -1.498052
# 2024-05-31   0.191847  -0.979062        NaN   0.146631        NaN  -1.559635
# 2024-06-30   0.193541  -0.968155        NaN   0.176745        NaN  -1.540567
# 2024-07-31   0.192589  -0.968484        NaN   0.152284        NaN  -1.542602
# 2024-08-31   0.216217  -0.666230        NaN   0.261396        NaN  -1.612245
#
# ...
